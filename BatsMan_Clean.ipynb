# %% [markdown]
# # Apply Cleaning logic on Bats man dataset which is downloaded from Kaggel

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Read Batsman dataset

# %%
df1=pd.read_csv(r"C:\Users\navee\Downloads\Batsman_Data.csv\Batsman_Data.csv")

# %% [markdown]
# # Print Batsman dataset

# %%
df1
# Out:
#        Unnamed: 0  Bat1 Runs  BF     SR 4s 6s    Opposition     Ground  \
# 0               1   DNB    -   -      -  -  -       v India     Nagpur
# 1               2   DNB    -   -      -  -  -       v India    Kolkata
# 2               3   DNB    -   -      -  -  -       v India      Delhi
# 3               4   DNB    -   -      -  -  -  v Bangladesh      Dhaka
# 4               5   DNB    -   -      -  -  -       v India      Dhaka
# ...           ...   ...  ...  ..    ... .. ..           ...        ...
# 11144       11145    46   46  61  75.40  6  1     v Ireland   Dehradun
# 11145       11146     3    3   6  50.00  0  0     v Ireland   Dehradun
# 11146       11147     1    1   8  12.50  0  0     v Ireland   Dehradun
# 11147       11148   DNB    -   -      -  -  -    v Scotland  Edinburgh
# 11148       11149  TDNB    -   -      -  -  -     v Ireland    Belfast
#
#         Start Date    Match_ID         Batsman  Player_ID
# ...

# %% [markdown]
# # Apply cleaning logic on Bats man dataset

# %%
col1 = ["Bat1"]
df1[col1] = df1[col1].apply(lambda x:x.str.strip("absent"))
print(df1)
# Out:
#        Unnamed: 0  Bat1 Runs  BF     SR 4s 6s    Opposition     Ground  \
# 0               1   DNB    -   -      -  -  -       v India     Nagpur
# 1               2   DNB    -   -      -  -  -       v India    Kolkata
# 2               3   DNB    -   -      -  -  -       v India      Delhi
# 3               4   DNB    -   -      -  -  -  v Bangladesh      Dhaka
# 4               5   DNB    -   -      -  -  -       v India      Dhaka
# ...           ...   ...  ...  ..    ... .. ..           ...        ...
# 11144       11145    46   46  61  75.40  6  1     v Ireland   Dehradun
# 11145       11146     3    3   6  50.00  0  0     v Ireland   Dehradun
# 11146       11147     1    1   8  12.50  0  0     v Ireland   Dehradun
# 11147       11148   DNB    -   -      -  -  -    v Scotland  Edinburgh
# 11148       11149  TDNB    -   -      -  -  -     v Ireland    Belfast
#
#         Start Date    Match_ID         Batsman  Player_ID
# ...

# %%
col1 = ["Bat1"]
df1[col1] = df1[col1].apply(lambda x:x.str.strip("DNB"))
print(df1)
# Out:
#        Unnamed: 0 Bat1 Runs  BF     SR 4s 6s    Opposition     Ground  \
# 0               1         -   -      -  -  -       v India     Nagpur
# 1               2         -   -      -  -  -       v India    Kolkata
# 2               3         -   -      -  -  -       v India      Delhi
# 3               4         -   -      -  -  -  v Bangladesh      Dhaka
# 4               5         -   -      -  -  -       v India      Dhaka
# ...           ...  ...  ...  ..    ... .. ..           ...        ...
# 11144       11145   46   46  61  75.40  6  1     v Ireland   Dehradun
# 11145       11146    3    3   6  50.00  0  0     v Ireland   Dehradun
# 11146       11147    1    1   8  12.50  0  0     v Ireland   Dehradun
# 11147       11148         -   -      -  -  -    v Scotland  Edinburgh
# 11148       11149    T    -   -      -  -  -     v Ireland    Belfast
#
#         Start Date    Match_ID         Batsman  Player_ID
# 0      18 Dec 2009  ODI # 2933   Oshane Thomas      49619
# ...

# %%
col1 = ["Bat1"]
df1[col1] = df1[col1].apply(lambda x:x.str.strip("sub"))
print(df1)
# Out:
#        Unnamed: 0 Bat1 Runs  BF     SR 4s 6s    Opposition     Ground  \
# 0               1         -   -      -  -  -       v India     Nagpur
# 1               2         -   -      -  -  -       v India    Kolkata
# 2               3         -   -      -  -  -       v India      Delhi
# 3               4         -   -      -  -  -  v Bangladesh      Dhaka
# 4               5         -   -      -  -  -       v India      Dhaka
# ...           ...  ...  ...  ..    ... .. ..           ...        ...
# 11144       11145   46   46  61  75.40  6  1     v Ireland   Dehradun
# 11145       11146    3    3   6  50.00  0  0     v Ireland   Dehradun
# 11146       11147    1    1   8  12.50  0  0     v Ireland   Dehradun
# 11147       11148         -   -      -  -  -    v Scotland  Edinburgh
# 11148       11149    T    -   -      -  -  -     v Ireland    Belfast
#
#         Start Date    Match_ID         Batsman  Player_ID
# 0      18 Dec 2009  ODI # 2933   Oshane Thomas      49619
# ...

# %%
col1 = ["Bat1"]
df1[col1] = df1[col1].apply(lambda x:x.str.strip("TDNB"))
print(df1)
# Out:
#        Unnamed: 0 Bat1 Runs  BF     SR 4s 6s    Opposition     Ground  \
# 0               1         -   -      -  -  -       v India     Nagpur
# 1               2         -   -      -  -  -       v India    Kolkata
# 2               3         -   -      -  -  -       v India      Delhi
# 3               4         -   -      -  -  -  v Bangladesh      Dhaka
# 4               5         -   -      -  -  -       v India      Dhaka
# ...           ...  ...  ...  ..    ... .. ..           ...        ...
# 11144       11145   46   46  61  75.40  6  1     v Ireland   Dehradun
# 11145       11146    3    3   6  50.00  0  0     v Ireland   Dehradun
# 11146       11147    1    1   8  12.50  0  0     v Ireland   Dehradun
# 11147       11148         -   -      -  -  -    v Scotland  Edinburgh
# 11148       11149         -   -      -  -  -     v Ireland    Belfast
#
#         Start Date    Match_ID         Batsman  Player_ID
# 0      18 Dec 2009  ODI # 2933   Oshane Thomas      49619
# ...

# %%
col1 = ["Runs","BF","SR","4s","6s"]
df1[col1] = df1[col1].apply(lambda x:x.str.strip("-"))
print(df1)
# Out:
#        Unnamed: 0 Bat1 Runs  BF     SR 4s 6s    Opposition     Ground  \
# 0               1                                  v India     Nagpur
# 1               2                                  v India    Kolkata
# 2               3                                  v India      Delhi
# 3               4                             v Bangladesh      Dhaka
# 4               5                                  v India      Dhaka
# ...           ...  ...  ...  ..    ... .. ..           ...        ...
# 11144       11145   46   46  61  75.40  6  1     v Ireland   Dehradun
# 11145       11146    3    3   6  50.00  0  0     v Ireland   Dehradun
# 11146       11147    1    1   8  12.50  0  0     v Ireland   Dehradun
# 11147       11148                               v Scotland  Edinburgh
# 11148       11149                                v Ireland    Belfast
#
#         Start Date    Match_ID         Batsman  Player_ID
# 0      18 Dec 2009  ODI # 2933   Oshane Thomas      49619
# ...

# %%
df3 = df1["Bat1"]==''
df3 = df1[~df3]
print(df3)
# Out:
#        Unnamed: 0 Bat1 Runs  BF     SR 4s 6s    Opposition       Ground  \
# 5               6   0*    0   8   0.00  0  0       v India        Dhaka
# 6               7   0*    0   0         0  0     v England     The Oval
# 9              10   1*    1   3  33.33  0  0     v England   Nottingham
# 10             11   0*    0   2   0.00  0  0   v Australia    Pallekele
# 11             12    0    0   2   0.00  0  0    v Pakistan  Dubai (DSC)
# ...           ...  ...  ...  ..    ... .. ..           ...          ...
# 11142       11143   0*    0   2   0.00  0  0  v Bangladesh    Abu Dhabi
# 11143       11144   15   15  46  32.60  1  0       v India  Dubai (DSC)
# 11144       11145   46   46  61  75.40  6  1     v Ireland     Dehradun
# 11145       11146    3    3   6  50.00  0  0     v Ireland     Dehradun
# 11146       11147    1    1   8  12.50  0  0     v Ireland     Dehradun
#
#         Start Date    Match_ID         Batsman  Player_ID
# ...

# %% [markdown]
# # Final cleaned Batsman dataset

# %%
df3.to_csv(r"C:\Users\navee\Downloads\Batsman_data.csv\Batsman_data_clean.csv",encoding ='utf-8')
